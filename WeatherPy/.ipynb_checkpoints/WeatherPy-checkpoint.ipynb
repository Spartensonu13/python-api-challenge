# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    time.sleep(1)        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as error:
        print("City not found. Skipping...", error)
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | badr hunayn
# Processing Record 3 of Set 1 | anibare
# City not found. Skipping... 'coord'
# Processing Record 4 of Set 1 | cabo san lucas
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | vernon
# Processing Record 8 of Set 1 | krutinka
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | waingapu
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | ketchikan
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | saudarkrokur
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | utrik
# Processing Record 17 of Set 1 | porto novo
# Processing Record 18 of Set 1 | badger
# Processing Record 19 of Set 1 | agat village
# Processing Record 20 of Set 1 | iskateley
# Processing Record 21 of Set 1 | kapuskasing
# Processing Record 22 of Set 1 | port mathurin
# Processing Record 23 of Set 1 | susuman
# Processing Record 24 of Set 1 | kapa'a
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | east ballina
# Processing Record 27 of Set 1 | remire-montjoly
# Processing Record 28 of Set 1 | palmer
# Processing Record 29 of Set 1 | amga
# Processing Record 30 of Set 1 | aksaray
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | rabo de peixe
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping... 'coord'
# Processing Record 35 of Set 1 | udachny
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | dudinka
# Processing Record 38 of Set 1 | kyzyl
# Processing Record 39 of Set 1 | chernyshevsk
# Processing Record 40 of Set 1 | aasiaat
# Processing Record 41 of Set 1 | sirte
# Processing Record 42 of Set 1 | kingston
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | chu
# Processing Record 46 of Set 1 | vorkuta
# Processing Record 47 of Set 1 | lihue
# Processing Record 48 of Set 1 | puerto natales
# Processing Record 49 of Set 1 | ravar
# Processing Record 50 of Set 1 | waitangi
# Processing Record 0 of Set 2 | seaside
# Processing Record 1 of Set 2 | coquimbo
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | vershino-darasunskiy
# Processing Record 4 of Set 2 | tobruk
# Processing Record 5 of Set 2 | olonkinbyen
# Processing Record 6 of Set 2 | sabang
# Processing Record 7 of Set 2 | miri
# Processing Record 8 of Set 2 | williams lake
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | west island
# Processing Record 11 of Set 2 | ishigaki
# Processing Record 12 of Set 2 | keetmanshoop
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | isafjordur
# Processing Record 15 of Set 2 | port saint john's
# Processing Record 16 of Set 2 | saipan
# Processing Record 17 of Set 2 | ngerengere
# Processing Record 18 of Set 2 | altai
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | wailua homesteads
# Processing Record 21 of Set 2 | la'ie
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 
# Processing Record 48 of Set 3 | fuvahmulah
# City not found. Skipping... 'coord'
# Processing Record 49 of Set 3 | champerico
# Processing Record 0 of Set 4 | kiunga
# Processing Record 1 of Set 4 | howrah
# Processing Record 2 of Set 4 | ust-nera
# Processing Record 3 of Set 4 | crane
# Processing Record 4 of Set 4 | vila velha
# Processing Record 5 of Set 4 | baharly
# Processing Record 6 of Set 4 | montepuez
# Processing Record 7 of Set 4 | puerto lempira
# Processing Record 8 of Set 4 | la sarre
# Processing Record 9 of Set 4 | papatowai
# Processing Record 10 of Set 4 | daru
# Processing Record 11 of Set 4 | chernyshevskiy
# Processing Record 12 of Set 4 | cudillero
# Processing Record 13 of Set 4 | nyurba
# Processing Record 14 of Set 4 | birobidzhan
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | salinas
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | luganville
# Processing Record 20 of Set 4 | mecitozu
# Processing Record 21 of Set 4 | alto araguaia
# Processing Record 22 of Set 4 | mahajanga
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | zhangjiakou shi xuanhua qu
# Processing Record 26 of Set 4 | katabu
# Processing Record 27 of Set 4 | puerto san carlos
# City not found. Skipping... 'coord'
# Processing Record 28 of Set 4 | alaghsas
# Processing Record 29 of Set 4 | mount pearl
# Processing Record 30 of Set 4 | kolonia
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | tsiombe
# Processing Record 33 of Set 4 | chui
# Processing Record 34 of Set 4 | torbat-e heydariyeh
# Processing Record 35 of Set 4 | al ghayzah
# Processing Record 36 of Set 4 | shache
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | naberera
# Processing Record 39 of Set 4 | severo-yeniseyskiy
# Processing Record 40 of Set 4 | fale old settlement
# Processing Record 41 of Set 4 | enewetak
# Processing Record 42 of Set 4 | canto do buriti
# Processing Record 43 of Set 4 | yarmouth
# Processing Record 44 of Set 4 | sanshui
# Processing Record 45 of Set 4 | narrabri
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | ihosy
# Processing Record 48 of Set 4 | amuntai
# Processing Record 49 of Set 4 | khandyga
# Processing Record 0 of Set 5 | kamyzyak
# Processing Record 1 of Set 5 | prince albert
# Processing Record 2 of Set 5 | tofol
# Processing Record 3 of Set 5 | paradip garh
# Processing Record 4 of Set 5 | kedougou
# Processing Record 5 of Set 5 | panama city beach
# Processing Record 6 of Set 5 | howard springs
# Processing Record 7 of Set 5 | hammerfest
# Processing Record 8 of Set 5 | san pedro
# Processing Record 9 of Set 5 | namibe
# Processing Record 10 of Set 5 | moires
# Processing Record 11 of Set 5 | queenstown
# Processing Record 12 of Set 5 | colares
# Processing Record 13 of Set 5 | quellon
# Processing Record 14 of Set 5 | la passe
# Processing Record 15 of Set 5 | tazovsky
# Processing Record 16 of Set 5 | calvi
# Processing Record 17 of Set 5 | canutama
# Processing Record 18 of Set 5 | vicente guerrero
# Processing Record 19 of Set 5 | salmon arm
# Processing Record 20 of Set 5 | rawson
# Processing Record 21 of Set 5 | karlskrona
# Processing Record 22 of Set 5 | saint-pierre
# Processing Record 23 of Set 5 | klyuchi
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | vilyuchinsk
# Processing Record 27 of Set 5 | chibougamau
# Processing Record 28 of Set 5 | lazaro cardenas
# Processing Record 29 of Set 5 | san luis de la loma
# Processing Record 30 of Set 5 | al qaryatayn
# Processing Record 31 of Set 5 | sorong
# Processing Record 32 of Set 5 | kargasok
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | buala
# Processing Record 36 of Set 5 | ust-tsilma
# Processing Record 37 of Set 5 | gordon
# Processing Record 38 of Set 5 | kuandian
# Processing Record 39 of Set 5 | jamestown
# Processing Record 40 of Set 5 | sogndal
# Processing Record 41 of Set 5 | el rama
# Processing Record 42 of Set 5 | st. john's
# Processing Record 43 of Set 5 | jackson
# Processing Record 44 of Set 5 | 'ohonua
# City not found. Skipping... 'coord'
# Processing Record 45 of Set 5 | acajutla
# Processing Record 46 of Set 5 | tralee
# Processing Record 47 of Set 5 | puerto deseado
# Processing Record 48 of Set 5 | port glaud
# City not found. Skipping... 'coord'
# Processing Record 49 of Set 5 | slave lake
# Processing Record 0 of Set 6 | harper
# Processing Record 1 of Set 6 | abadan
# Processing Record 2 of Set 6 | tindouf
# Processing Record 3 of Set 6 | taltal
# Processing Record 4 of Set 6 | dawei
# Processing Record 5 of Set 6 | oum hadjer
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | rakops
# Processing Record 8 of Set 6 | georgetown
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | happy valley-goose bay
# Processing Record 11 of Set 6 | jimo
# Processing Record 12 of Set 6 | scottburgh
# Processing Record 13 of Set 6 | hohhot
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | houghton
# Processing Record 16 of Set 6 | copala
# Processing Record 17 of Set 6 | villa gesell
# Processing Record 18 of Set 6 | castillos
# Processing Record 19 of Set 6 | bridgewater
# Processing Record 20 of Set 6 | toga village
# City not found. Skipping... 'coord'
# Processing Record 21 of Set 6 | diagonal mar
# Processing Record 22 of Set 6 | angaur state
# Processing Record 23 of Set 6 | nema
# Processing Record 24 of Set 6 | tambacounda
# Processing Record 25 of Set 6 | mount gambier
# Processing Record 26 of Set 6 | raduzhny
# Processing Record 27 of Set 6 | port hueneme
# Processing Record 28 of Set 6 | sinabang
# Processing Record 29 of Set 6 | rivne
# Processing Record 30 of Set 6 | axim
# Processing Record 31 of Set 6 | tres lagoas
# Processing Record 32 of Set 6 | obertshausen
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | opuwo
# Processing Record 35 of Set 6 | bamboo flat
# Processing Record 36 of Set 6 | wanning
# Processing Record 37 of Set 6 | velingara
# Processing Record 38 of Set 6 | rwamagana
# Processing Record 39 of Set 6 | westport
# Processing Record 40 of Set 6 | urengoy
# Processing Record 41 of Set 6 | nova sintra
# Processing Record 42 of Set 6 | lensk
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | labytnangi
# Processing Record 45 of Set 6 | betio village
# Processing Record 46 of Set 6 | chonchi
# Processing Record 47 of Set 6 | gaalkacyo
# Processing Record 48 of Set 6 | trabzon
# Processing Record 49 of Set 6 | ouellah
# City not found. Skipping... 'coord'
# Processing Record 0 of Set 7 | kataragama
# City not found. Skipping... 'coord'
# Processing Record 1 of Set 7 | santa elena de uairen
# Processing Record 2 of Set 7 | darwin
# Processing Record 3 of Set 7 | irymple
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | smithers
# Processing Record 6 of Set 7 | labrador city
# Processing Record 7 of Set 7 | keflavik
# Processing Record 8 of Set 7 | kavaratti
# Processing Record 9 of Set 7 | greenville
# Processing Record 10 of Set 7 | nan
# Processing Record 11 of Set 7 | northam
# Processing Record 12 of Set 7 | xilin hot
# Processing Record 13 of Set 7 | jurbarkas
# Processing Record 14 of Set 7 | tynda
# Processing Record 15 of Set 7 | chinchilla
# Processing Record 16 of Set 7 | ambon
# Processing Record 17 of Set 7 | iquique
# Processing Record 18 of Set 7 | isle of lewis
# City not found. Skipping... 'coord'
# Processing Record 19 of Set 7 | sovetskaya gavan'
# Processing Record 20 of Set 7 | hawkesbury
# Processing Record 21 of Set 7 | suva
# Processing Record 22 of Set 7 | palikir - national government center
# Processing Record 23 of Set 7 | samut sakhon
# Processing Record 24 of Set 7 | hadibu
# Processing Record 25 of Set 7 | bantogon
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | singrauli
# Processing Record 28 of Set 7 | uturoa
# Processing Record 29 of Set 7 | koryazhma
# Processing Record 30 of Set 7 | chilca
# Processing Record 31 of Set 7 | sukhobezvodnoye
# Processing Record 32 of Set 7 | lupiro
# Processing Record 33 of Set 7 | itaituba
# Processing Record 34 of Set 7 | rongelap
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | fisterra
# Processing Record 37 of Set 7 | kyzyl-mazhalyk
# Processing Record 38 of Set 7 | yagry
# City not found. Skipping... 'coord'
# Processing Record 39 of Set 7 | lamu
# Processing Record 40 of Set 7 | devinuwara
# City not found. Skipping... 'coord'
# Processing Record 41 of Set 7 | trenton
# Processing Record 42 of Set 7 | gazli
# Processing Record 43 of Set 7 | nsanje
# Processing Record 44 of Set 7 | vohipaho
# City not found. Skipping... 'coord'
# Processing Record 45 of Set 7 | blair
# Processing Record 46 of Set 7 | obligado
# Processing Record 47 of Set 7 | santa coloma de farners
# Processing Record 48 of Set 7 | boende
# Processing Record 49 of Set 7 | tanggu
# Processing Record 0 of Set 8 | bubaque
# Processing Record 1 of Set 8 | guarapari
# Processing Record 2 of Set 8 | kisangani
# Processing Record 3 of Set 8 | colonia
# Processing Record 24 of Set 9 | sarny
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | caleta de carquin
# Processing Record 27 of Set 9 | el porvenir
# Processing Record 28 of Set 9 | sandnessjoen
# Processing Record 29 of Set 9 | priladozhskiy
# Processing Record 30 of Set 9 | lauro de freitas
# Processing Record 31 of Set 9 | cadale
# Processing Record 32 of Set 9 | coruripe
# Processing Record 33 of Set 9 | vanimo
# Processing Record 34 of Set 9 | mongo
# Processing Record 35 of Set 9 | caconda
# Processing Record 36 of Set 9 | vorgashor
# Processing Record 37 of Set 9 | nadvoitsy
# Processing Record 38 of Set 9 | cascais
# Processing Record 39 of Set 9 | lashio
# Processing Record 40 of Set 9 | lorengau
# Processing Record 41 of Set 9 | vila franca do campo
# Processing Record 42 of Set 9 | okha
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | akureyri
# Processing Record 45 of Set 9 | bingol
# Processing Record 46 of Set 9 | urangan
# Processing Record 47 of Set 9 | vadso
# Processing Record 48 of Set 9 | kawthoung
# City not found. Skipping... 'coord'
# Processing Record 49 of Set 9 | petropavl
# Processing Record 0 of Set 10 | encruzilhada do sul
# Processing Record 1 of Set 10 | isabela
# Processing Record 2 of Set 10 | tidjikja
# Processing Record 3 of Set 10 | aguazul
# Processing Record 4 of Set 10 | west bay
# Processing Record 5 of Set 10 | holualoa
# Processing Record 6 of Set 10 | mirpur sakro
# Processing Record 7 of Set 10 | colon
# Processing Record 8 of Set 10 | mao
# Processing Record 9 of Set 10 | najran
# Processing Record 10 of Set 10 | luanda
# Processing Record 11 of Set 10 | indramayu
# Processing Record 12 of Set 10 | magelang
# Processing Record 13 of Set 10 | sao vicente
# Processing Record 14 of Set 10 | natal
# Processing Record 15 of Set 10 | bandarbeyla
# Processing Record 16 of Set 10 | bo phloi
# Processing Record 17 of Set 10 | mungwi
# Processing Record 18 of Set 10 | kourou
# Processing Record 19 of Set 10 | homer
# Processing Record 20 of Set 10 | ahoada
# Processing Record 21 of Set 10 | aljezur
# Processing Record 22 of Set 10 | tanumah
# Processing Record 23 of Set 10 | kailua-kona
# Processing Record 24 of Set 10 | el dorado
# Processing Record 25 of Set 10 | flin flon
# Processing Record 26 of Set 10 | nalerigu
# City not found. Skipping... 'coord'
# Processing Record 27 of Set 10 | panaba
# Processing Record 28 of Set 10 | puerto aysen
# Processing Record 29 of Set 10 | qarazhal
# Processing Record 30 of Set 10 | callao
# Processing Record 31 of Set 10 | jwaneng
# Processing Record 32 of Set 10 | cannonvale
# Processing Record 33 of Set 10 | grand-lahou
# Processing Record 34 of Set 10 | namsos
# Processing Record 35 of Set 10 | saint-philippe
# Processing Record 36 of Set 10 | siuntio
# Processing Record 37 of Set 10 | lake havasu city
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | mount isa
# Processing Record 40 of Set 10 | sur
# Processing Record 41 of Set 10 | beloyarskiy
# Processing Record 42 of Set 10 | lagos
# Processing Record 43 of Set 10 | kurchatov
# Processing Record 44 of Set 10 | bela
# Processing Record 45 of Set 10 | katsuura
# Processing Record 46 of Set 10 | francistown
# Processing Record 47 of Set 10 | grand-bassam
# Processing Record 48 of Set 10 | shenkursk
# Processing Record 49 of Set 10 | turuntayevo
# Processing Record 0 of Set 11 | russkaya polyana
# Processing Record 1 of Set 11 | haparanda
# Processing Record 2 of Set 11 | fort mcmurray
# Processing Record 3 of Set 11 | prescott
# Processing Record 4 of Set 11 | smara
# Processing Record 5 of Set 11 | puerto madryn
# Processing Record 6 of Set 11 | bardai
# Processing Record 7 of Set 11 | abu zabad
# Processing Record 8 of Set 11 | muang khong
# Processing Record 9 of Set 11 | verkhnevilyuysk
# Processing Record 10 of Set 11 | gadzhiyevo
# Processing Record 11 of Set 11 | mianwali
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | morant bay
# Processing Record 14 of Set 11 | zachary
# Processing Record 15 of Set 11 | bowral
# Processing Record 16 of Set 11 | revda
# Processing Record 17 of Set 11 | ballina
# Processing Record 18 of Set 11 | oranjemund
# Processing Record 19 of Set 11 | fukuecho
# Processing Record 20 of Set 11 | kone
# Processing Record 21 of Set 11 | jolo
# Processing Record 22 of Set 11 | lisakovsk
# Processing Record 23 of Set 11 | puerto baquerizo moreno
# Processing Record 24 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 25 of Set 11 | orange walk
# Processing Record 26 of Set 11 | kenai
# Processing Record 27 of Set 11 | keyser
# Processing Record 28 of Set 11 | aripuana
# Processing Record 29 of Set 11 | rodolfo sanchez taboada
# Processing Record 30 of Set 11 | bhisho
# Processing Record 31 of Set 11 | shimanovsk
# Processing Record 32 of Set 11 | mwinilunga
# Processing Record 33 of Set 11 | puerto san jose
# Processing Record 34 of Set 11 | jijiga
# Processing Record 35 of Set 11 | barclayville
# Processing Record 36 of Set 11 | copiapo
# Processing Record 37 of Set 11 | kharod
# Processing Record 38 of Set 11 | ibarreta
# Processing Record 39 of Set 11 | xining
# Processing Record 40 of Set 11 | talcahuano
# Processing Record 41 of Set 11 | tumayr
# Processing Record 42 of Set 11 | fuglafjordur
# Processing Record 43 of Set 11 | saint-joseph
# Processing Record 44 of Set 11 | grand falls-windsor
# Processing Record 45 of Set 11 | jetpur
# Processing Record 46 of Set 11 | nalut
# Processing Record 47 of Set 11 | nabire
# Processing Record 48 of Set 11 | wezembeek-oppem
# Processing Record 49 of Set 11 | saldanha
# Processing Record 0 of Set 12 | cable beach
# City not found. Skipping... 'coord'
# Processing Record 1 of Set 12 | aral
# Processing Record 2 of Set 12 | inda silase
# Processing Record 3 of Set 12 | yeppoon
# Processing Record 4 of Set 12 | polla
# Processing Record 5 of Set 12 | bim son
# Processing Record 6 of Set 12 | villa hidalgo
# Processing Record 7 of Set 12 | saint-esteve
# Processing Record 8 of Set 12 | bhandaria
# Processing Record 9 of Set 12 | dwarka
# Processing Record 10 of Set 12 | runka
# Processing Record 11 of Set 12 | pacocha
# Processing Record 12 of Set 12 | san giorgio del sannio
# Processing Record 13 of Set 12 | zhuanghe
# Processing Record 14 of Set 12 | dumingag
# Processing Record 15 of Set 12 | pervomayskoye
# Processing Record 16 of Set 12 | waddan
# Processing Record 17 of Set 12 | kirensk
# Processing Record 18 of Set 12 | wuxi
# Processing Record 19 of Set 12 | hatillo
# Processing Record 20 of Set 12 | namdrik
# Processing Record 21 of Set 12 | kalaleh
# Processing Record 22 of Set 12 | viqueque
# Processing Record 23 of Set 12 | jiquilisco
# Processing Record 24 of Set 12 | midvagur
# Processing Record 25 of Set 12 | khorixas
# Processing Record 26 of Set 12 | vredendal
# Processing Record 27 of Set 12 | ebon
# Processing Record 28 of Set 12 | berdigestyakh
# Processing Record 29 of Set 12 | cidreira
# Processing Record 30 of Set 12 | sal rei
# Processing Record 31 of Set 12 | miandrivazo
# Processing Record 32 of Set 12 | gizo
# Processing Record 33 of Set 12 | leava
# Processing Record 34 of Set 12 | aringay
# Processing Record 35 of Set 12 | walvis bay
# Processing Record 36 of Set 12 | fortuna
# Processing Record 37 of Set 12 | dickinson
# Processing Record 38 of Set 12 | concepcion
# Processing Record 39 of Set 12 | iola
# Processing Record 40 of Set 12 | ajaccio
# Processing Record 41 of Set 12 | ende
# Processing Record 42 of Set 12 | toropets
# Processing Record 43 of Set 12 | constantia
# Processing Record 44 of Set 12 | tazacorte
# Processing Record 45 of Set 12 | vilyuysk
# Processing Record 46 of Set 12 | las khorey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     21.60        63          64
# 1        badr hunayn  23.7829   38.7905     28.51        32           0
# 2     cabo san lucas  22.8909 -109.9124     30.90        46           0
# 3            talnakh  69.4865   88.3972    -13.22        77          29
# 4  port-aux-francais -49.3500   70.2167      3.77        89          87
#
#    Wind Speed Country        Date
# 0        8.73      PN  1714930823
# 1        1.52      SA  1714930922
# 2        1.79      MX  1714930370
# 3        1.81      RU  1714930928
# 4        3.41      TF  1714930930

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     21.60        63          64
# 1              badr hunayn  23.7829   38.7905     28.51        32           0
# 2           cabo san lucas  22.8909 -109.9124     30.90        46           0
# 3                  talnakh  69.4865   88.3972    -13.22        77          29
# 4        port-aux-francais -49.3500   70.2167      3.77        89          87
#
#          Wind Speed Country        Date
# City_ID
# 0              8.73      PN  1714930823
# 1              1.52      SA  1714930922
# 2              1.79      MX  1714930370
# 3              1.81      RU  1714930928
# 4              3.41      TF  1714930930

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter("Lat","Max Temp" , s = 10, c = "blue")

# Incorporate the other graph properties
plt.title("City Latitude vs.Max temprature(2024-5-4)")
plt.xlabel("Latitude")
plt.ylabel("Max Temprature(C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter("Lat","Humidity" , s = 10, c = "blue" )

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(2024-5-4)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter("Lat","Cloudiness" , s = 10, c = "blue" )

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(2024-5-4)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter("Lat","Wind Speed" , s = 10, c = "blue" )

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2024-5-4)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def createLinearRegressionPlot(df, x_column, y_column, x_label, y_label, x_pos, y_pos):
    x_values = df[x_column]
    y_values = df[y_column]
    linear_regression = linregress(x_values, y_values)
    print(f"The r-value is: {linear_regression.rvalue**2}")
    
    linregressValues = x_values * linear_regression.slope + linear_regression.intercept
    line_annotation = f"y = {linear_regression.slope:.2f}x + {linear_regression.intercept:.2f}"
    print(line_annotation)
    
    plt.scatter(x_values, y_values, facecolor="blue", edgecolor="black", s=50)
    plt.plot(x_values, linregressValues, "r-")
    plt.annotate(line_annotation, (x_pos,y_pos),fontsize=16, color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           badr hunayn  23.7829   38.7905     28.51        32           0
# 2        cabo san lucas  22.8909 -109.9124     30.90        46           0
# 3               talnakh  69.4865   88.3972    -13.22        77          29
# 5                vernon  50.2581 -119.2691     17.35        43         100
# 6              krutinka  56.0055   71.5113      1.56        66          42
#
#          Wind Speed Country        Date
# City_ID
# 1              1.52      SA  1714930922
# 2              1.79      MX  1714930370
# 3              1.81      RU  1714930928
# 5              0.51      CA  1714930932
# 6              4.17      RU  1714930934

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          adamstown -25.0660 -130.1015     21.60        63
# 4                  port-aux-francais -49.3500   70.2167      3.77        89
# 7                            ushuaia -54.8000  -68.3000      2.81        75
# 8                           waingapu  -9.6567  120.2641     24.69        83
# 9        edinburgh of the seven seas -37.0676  -12.3116     13.97        67
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                64        8.73      PN  1714930823
# 4                87        3.41      TF  1714930930
# 7               100       10.29      AR  1714930878
# 8                72        2.93      ID  1714930938
# 9                64       13.06      SH  1714930792

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
createLinearRegressionPlot(northern_hemi_df, "Lat", "Max Temp", "Latitude", "Max Temp", 40, 40)
# Out:
# The r-value is: 0.7454879421544933
# y = -0.53x + 36.77

# %%
# Linear regression on Southern Hemisphere
createLinearRegressionPlot(southern_hemi_df, "Lat", "Max Temp", "Latitude", "Max Temp", -55, 35)
# Out:
# The r-value is: 0.5834108967797011
# y = 0.43x + 30.01

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
createLinearRegressionPlot(northern_hemi_df, "Lat", "Humidity", "Latitude", "Humidity", 45, 10)
# Out:
# The r-value is: 0.036049646295260765
# y = 0.23x + 60.75

# %%
# Southern Hemisphere
createLinearRegressionPlot(southern_hemi_df, "Lat", "Humidity", "Latitude", "Humidity", -55, 30)
# Out:
# The r-value is: 0.007294975046708304
# y = 0.13x + 75.54

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
createLinearRegressionPlot(northern_hemi_df, "Lat", "Cloudiness", "Latitude", "Cloudiness", 45, 30)
# Out:
# The r-value is: 0.0267048151317325
# y = 0.31x + 47.76

# %%
# Southern Hemisphere
createLinearRegressionPlot(southern_hemi_df, "Lat", "Cloudiness", "Latitude", "Cloudiness", -55, 20)
# Out:
# The r-value is: 0.03545999755236088
# y = 0.52x + 58.79

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
createLinearRegressionPlot(northern_hemi_df, "Lat", "Wind Speed", "Latitude", "Wind Speed", 0, 12.5)
# Out:
# The r-value is: 0.005565906566692757
# y = -0.01x + 4.16

# %%
# Southern Hemisphere
createLinearRegressionPlot(southern_hemi_df, "Lat", "Wind Speed", "Latitude", "Wind Speed", -55, 11)
# Out:
# The r-value is: 0.027666356446727238
# y = -0.03x + 3.03

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
